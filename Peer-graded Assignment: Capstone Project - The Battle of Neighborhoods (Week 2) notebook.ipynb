# %% [markdown]
# # A Recommender System for Grocery Contractor

# %%
# importing libraries
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
from bs4 import BeautifulSoup
import requests # library to handle requests
import json # library to handle JSON files
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
import geopy.geocoders # convert an address into latitude and longitude values

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries are imported.')
# Out:
# Libraries are imported.

# %% [markdown]
# # Postal Codes in Toronto

# %%
# Loading the dataset which is about postal codes in Toronto
# This dataset was created in week 3. 
df_toronto = pd.read_csv('toronto_base.csv')
df_toronto.head()
# Out:
#   Postcode      Borough                            Neighborhood Postal Code  \
# 0      M1B  Scarborough                          Rouge, Malvern         M1B
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union         M1C
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill         M1E
# 3      M1G  Scarborough                                  Woburn         M1G
# 4      M1H  Scarborough                               Cedarbrae         M1H
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476

# %% [markdown]
# # Create a Map of Toronto City (with its Postal Codes' Regions)

# %%
# for the city Toronto, latitude and longtitude are manually extracted via google search
toronto_latitude = 43.6543; toronto_longitude = -79.3860
map_toronto = folium.Map(location = [toronto_latitude, toronto_longitude], zoom_start = 10.7)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_toronto['Latitude'], df_toronto['Longitude'], df_toronto['Borough'], df_toronto['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_toronto)  
    

map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Focusing on the "Downtown Toronto" Borough in Toronto (its neighborhoods)

# %%
df_toronto['Borough'] == 'Downtown Toronto'

# selecting only neighborhoods regarding to "Scarborough" borough.
dt_data = df_toronto[df_toronto['Borough'] == 'Downtown Toronto']
dt_data = dt_data.reset_index(drop=True)#.drop(columns = 'Unnamed: 0')
dt_data
# Out:
#    Postcode           Borough  \
# 0       M4W  Downtown Toronto
# 1       M4X  Downtown Toronto
# 2       M4Y  Downtown Toronto
# 3       M5A  Downtown Toronto
# 4       M5B  Downtown Toronto
# 5       M5C  Downtown Toronto
# 6       M5E  Downtown Toronto
# 7       M5G  Downtown Toronto
# 8       M5H  Downtown Toronto
# 9       M5J  Downtown Toronto
# 10      M5K  Downtown Toronto
# 11      M5L  Downtown Toronto
# 12      M5S  Downtown Toronto
# 13      M5T  Downtown Toronto
# 14      M5V  Downtown Toronto
# 15      M5W  Downtown Toronto
# 16      M5X  Downtown Toronto
# 17      M6G  Downtown Toronto
#
#                                          Neighborhood Postal Code   Latitude  \
# 0                                            Rosedale         M4W  43.679563
# 1                         Cabbagetown, St. James Town         M4X  43.667967
# 2                                Church and Wellesley         M4Y  43.665860
# 3                           Harbourfront, Regent Park         M5A  43.654260
# 4                            Ryerson, Garden District         M5B  43.657162
# 5                                      St. James Town         M5C  43.651494
# 6                                         Berczy Park         M5E  43.644771
# 7                                  Central Bay Street         M5G  43.657952
# 8                            Adelaide, King, Richmond         M5H  43.650571
# 9   Harbourfront East, Toronto Islands, Union Station         M5J  43.640816
# 10           Design Exchange, Toronto Dominion Centre         M5K  43.647177
# 11                     Commerce Court, Victoria Hotel         M5L  43.648198
# 12                     Harbord, University of Toronto         M5S  43.662696
# 13          Chinatown, Grange Park, Kensington Market         M5T  43.653206
# 14  CN Tower, Bathurst Quay, Island airport, Harbo...         M5V  43.628947
# 15                    Stn A PO Boxes 25 The Esplanade         M5W  43.646435
# 16             First Canadian Place, Underground city         M5X  43.648429
# 17                                           Christie         M6G  43.669542
#
#     Longitude
# 0  -79.377529
# 1  -79.367675
# 2  -79.383160
# 3  -79.360636
# 4  -79.378937
# 5  -79.375418
# 6  -79.373306
# 7  -79.387383
# 8  -79.384568
# 9  -79.381752
# 10 -79.381576
# 11 -79.379817
# 12 -79.400049
# 13 -79.400049
# 14 -79.394420
# 15 -79.374846
# 16 -79.382280
# 17 -79.422564

# %% [markdown]
# # Create a Map of Downtown Toronto and Its Neighbourhoods

# %%
address_scar = 'Downtown Toronto, Toronto'
latitude_scar = 43.6543
longitude_scar = -79.3860
print('The geograpical coordinate of "Downtown Toronto" are: {}, {}.'.format(latitude_scar, longitude_scar))

map_DowntownToronto = folium.Map(location=[latitude_scar, longitude_scar], zoom_start=11.5)

# add markers to map
for lat, lng, label in zip(dt_data['Latitude'], dt_data['Longitude'], dt_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius = 10,
        popup = label,
        color ='blue',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.7).add_to(map_DowntownToronto)  
    
map_DowntownToronto
# Out:
# The geograpical coordinate of "Downtown Toronto" are: 43.6543, -79.386.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def foursquare_crawler (postal_code_list, neighborhood_list, lat_list, lng_list, LIMIT = 500, radius = 1000):
    result_ds = []
    counter = 0
    for postal_code, neighborhood, lat, lng in zip(postal_code_list, neighborhood_list, lat_list, lng_list):
         
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, CLIENT_SECRET, VERSION, 
            lat, lng, radius, LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        tmp_dict = {}
        tmp_dict['Postal Code'] = postal_code; tmp_dict['Neighborhood(s)'] = neighborhood; 
        tmp_dict['Latitude'] = lat; tmp_dict['Longitude'] = lng;
        tmp_dict['Crawling_result'] = results;
        result_ds.append(tmp_dict)
        counter += 1
        print('{}.'.format(counter))
        print('Data is Obtained, for the Postal Code {} (and Neighborhoods {}) SUCCESSFULLY.'.format(postal_code, neighborhood))
    return result_ds;

# %%
# @hiddel_cell
CLIENT_ID = 'POXL4O3TH0RPS0ZN1LL4IT4JLVKXOWAPOISEDXJ3FBB5HOU0' # your Foursquare ID
CLIENT_SECRET = 'AC2HM0D5AJVSGNBSAQTEPMXIEI2MXE0AV3DP1YS3XESGHBTO' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# # Crawling Internet (in fact only Foursquare database) for Venues in the Neighborhoods inside "Downtown Toronto"

# %%
print('Crawling different neighborhoods inside "Downtown Toronto"')
dt_foursquare_dataset = foursquare_crawler(list(dt_data['Postcode']),
                                                   list(dt_data['Neighborhood']),
                                                   list(dt_data['Latitude']),
                                                   list(dt_data['Longitude']),)
# Out:
# Crawling different neighborhoods inside "Downtown Toronto"
# 1.
# Data is Obtained, for the Postal Code M4W (and Neighborhoods Rosedale) SUCCESSFULLY.
# 2.
# Data is Obtained, for the Postal Code M4X (and Neighborhoods Cabbagetown, St. James Town) SUCCESSFULLY.
# 3.
# Data is Obtained, for the Postal Code M4Y (and Neighborhoods Church and Wellesley) SUCCESSFULLY.
# 4.
# Data is Obtained, for the Postal Code M5A (and Neighborhoods Harbourfront, Regent Park) SUCCESSFULLY.
# 5.
# Data is Obtained, for the Postal Code M5B (and Neighborhoods Ryerson, Garden District) SUCCESSFULLY.
# 6.
# Data is Obtained, for the Postal Code M5C (and Neighborhoods St. James Town) SUCCESSFULLY.
# 7.
# Data is Obtained, for the Postal Code M5E (and Neighborhoods Berczy Park) SUCCESSFULLY.
# 8.
# Data is Obtained, for the Postal Code M5G (and Neighborhoods Central Bay Street) SUCCESSFULLY.
# 9.
# Data is Obtained, for the Postal Code M5H (and Neighborhoods Adelaide, King, Richmond) SUCCESSFULLY.
# 10.
# Data is Obtained, for the Postal Code M5J (and Neighborhoods Harbourfront East, Toronto Islands, Union Station) SUCCESSFULLY.
# 11.
# Data is Obtained, for the Postal Code M5K (and Neighborhoods Design Exchange, Toronto Dominion Centre) SUCCESSFULLY.
# 12.
# Data is Obtained, for the Postal Code M5L (and Neighborhoods Commerce Court, Victoria Hotel) SUCCESSFULLY.
# 13.
# Data is Obtained, for the Postal Code M5S (and Neighborhoods Harbord, University of Toronto) SUCCESSFULLY.
# 14.
# Data is Obtained, for the Postal Code M5T (and Neighborhoods Chinatown, Grange Park, Kensington Market) SUCCESSFULLY.
# 15.
# Data is Obtained, for the Postal Code M5V (and Neighborhoods CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara) SUCCESSFULLY.
# 16.
# Data is Obtained, for the Postal Code M5W (and Neighborhoods Stn A PO Boxes 25 The Esplanade) SUCCESSFULLY.
# 17.
# Data is Obtained, for the Postal Code M5X (and Neighborhoods First Canadian Place, Underground city) SUCCESSFULLY.
# 18.
# Data is Obtained, for the Postal Code M6G (and Neighborhoods Christie) SUCCESSFULLY.

# %% [markdown]
# # Breakpoint:
# # Saving results of Foursquare, so that we would not need to connect every time to Foursquare (and use our portions) .

# %%
import pickle
with open("dt_foursquare_dataset.txt", "wb") as fp:   #Pickling
    pickle.dump(dt_foursquare_dataset, fp)
print('Received Data from Internet is Saved to Computer.')
# Out:
# Received Data from Internet is Saved to Computer.

# %%
with open("dt_foursquare_dataset.txt", "rb") as fp:   # Unpickling
    dt_foursquare_dataset = pickle.load(fp)

# %% [markdown]
# # Cleaning the RAW Data Received from Foursquare Database

# %%
# This function is created to connect to the saved list which is the received database. It will extract each venue 
# for every neighborhood inside the database

def get_venue_dataset(foursquare_dataset):
    result_df = pd.DataFrame(columns = ['Postal Code', 'Neighborhood', 
                                           'Neighborhood Latitude', 'Neighborhood Longitude',
                                          'Venue', 'Venue Summary', 'Venue Category', 'Distance'])
    # print(result_df)
    
    for neigh_dict in foursquare_dataset:
        postal_code = neigh_dict['Postal Code']; neigh = neigh_dict['Neighborhood(s)']
        lat = neigh_dict['Latitude']; lng = neigh_dict['Longitude']
        print('Number of Venuse in Coordination "{}" Posal Code and "{}" Negihborhood(s) is:'.format(postal_code, neigh))
        print(len(neigh_dict['Crawling_result']))
        
        for venue_dict in neigh_dict['Crawling_result']:
            summary = venue_dict['reasons']['items'][0]['summary']
            name = venue_dict['venue']['name']
            dist = venue_dict['venue']['location']['distance']
            cat =  venue_dict['venue']['categories'][0]['name']
            
            
            # print({'Postal Code': postal_code, 'Neighborhood': neigh, 
            #                   'Neighborhood Latitude': lat, 'Neighborhood Longitude':lng,
            #                   'Venue': name, 'Venue Summary': summary, 
            #                   'Venue Category': cat, 'Distance': dist})
            
            result_df = result_df.append({'Postal Code': postal_code, 'Neighborhood': neigh, 
                              'Neighborhood Latitude': lat, 'Neighborhood Longitude':lng,
                              'Venue': name, 'Venue Summary': summary, 
                              'Venue Category': cat, 'Distance': dist}, ignore_index = True)
            # print(result_df)
    
    return(result_df)

# %%
dt_venues = get_venue_dataset(dt_foursquare_dataset)
# Out:
# Number of Venuse in Coordination "M4W" Posal Code and "Rosedale" Negihborhood(s) is:
# 23
# Number of Venuse in Coordination "M4X" Posal Code and "Cabbagetown, St. James Town" Negihborhood(s) is:
# 38
# Number of Venuse in Coordination "M4Y" Posal Code and "Church and Wellesley" Negihborhood(s) is:
# 100
# Number of Venuse in Coordination "M5A" Posal Code and "Harbourfront, Regent Park" Negihborhood(s) is:
# 100
# Number of Venuse in Coordination "M5B" Posal Code and "Ryerson, Garden District" Negihborhood(s) is:
# 100
# Number of Venuse in Coordination "M5C" Posal Code and "St. James Town" Negihborhood(s) is:
# 100
# Number of Venuse in Coordination "M5E" Posal Code and "Berczy Park" Negihborhood(s) is:
# 100
# Number of Venuse in Coordination "M5G" Posal Code and "Central Bay Street" Negihborhood(s) is:
# 100
# Number of Venuse in Coordination "M5H" Posal Code and "Adelaide, King, Richmond" Negihborhood(s) is:
# 100
# Number of Venuse in Coordination "M5J" Posal Code and "Harbourfront East, Toronto Islands, Union Station" Negihborhood(s) is:
# 100
# Number of Venuse in Coordination "M5K" Posal Code and "Design Exchange, Toronto Dominion Centre" Negihborhood(s) is:
# 100
# Number of Venuse in Coordination "M5L" Posal Code and "Commerce Court, Victoria Hotel" Negihborhood(s) is:
# 100
# Number of Venuse in Coordination "M5S" Posal Code and "Harbord, University of Toronto" Negihborhood(s) is:
# 100
# Number of Venuse in Coordination "M5T" Posal Code and "Chinatown, Grange Park, Kensington Market" Negihborhood(s) is:
# 100
# Number of Venuse in Coordination "M5V" Posal Code and "CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara" Negihborhood(s) is:
# 15
# Number of Venuse in Coordination "M5W" Posal Code and "Stn A PO Boxes 25 The Esplanade" Negihborhood(s) is:
# 100
# Number of Venuse in Coordination "M5X" Posal Code and "First Canadian Place, Underground city" Negihborhood(s) is:
# 100
# Number of Venuse in Coordination "M6G" Posal Code and "Christie" Negihborhood(s) is:
# 100

# %% [markdown]
# # Showing Venues for Each Neighborhood in Downtown Toronto

# %%
dt_venues.head()
# Out:
#   Postal Code Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0         M4W     Rosedale              43.679563              -79.377529
# 1         M4W     Rosedale              43.679563              -79.377529
# 2         M4W     Rosedale              43.679563              -79.377529
# 3         M4W     Rosedale              43.679563              -79.377529
# 4         M4W     Rosedale              43.679563              -79.377529
#
#                       Venue         Venue Summary       Venue Category  \
# 0         Summerhill Market  This spot is popular        Grocery Store
# 1               Black Camel  This spot is popular            BBQ Joint
# 2  Toronto Lawn Tennis Club  This spot is popular   Athletics & Sports
# 3                    Tinuno  This spot is popular  Filipino Restaurant
# 4               Pie Squared  This spot is popular             Pie Shop
#
#   Distance
# 0      764
# 1      994
# 2      896
# 3      945
# 4      826

# %%
dt_venues = dt_venues.replace({'Neighborhood': 'Neighborhood_Venue'})

# %% [markdown]
# # Breakpoint:
# # End of Processing the Retrieved Information from Foursquare
# # Saving a Cleaned Version of DataFrame as the Results from Foursquare

# %%
dt_venues.to_csv('dt_venues.csv')

# %% [markdown]
# # Loading Data from File (Saved "Foursquare " DataFrame for Venues)

# %%
dt_venues = pd.read_csv('dt_venues.csv')

# %% [markdown]
# # Some Summary Information about Neighborhoods inside "Downtown Toronto"

# %%
neigh_list = list(dt_venues['Neighborhood'].unique())
print('Number of Neighborhoods inside Downtown Toronto:')
print(len(neigh_list))
print('List of Neighborhoods inside Downtown Toronto:')
neigh_list
# Out:
# Number of Neighborhoods inside Downtown Toronto:
# 18
# List of Neighborhoods inside Downtown Toronto:
# ['Rosedale',
#  'Cabbagetown, St. James Town',
#  'Church and Wellesley',
#  'Harbourfront, Regent Park',
#  'Ryerson, Garden District',
#  'St. James Town',
#  'Berczy Park',
#  'Central Bay Street',
#  'Adelaide, King, Richmond',
#  'Harbourfront East, Toronto Islands, Union Station',
#  'Design Exchange, Toronto Dominion Centre',
#  'Commerce Court, Victoria Hotel',
#  'Harbord, University of Toronto',
#  'Chinatown, Grange Park, Kensington Market',
#  'CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara',
#  'Stn A PO Boxes 25 The Esplanade',
#  'First Canadian Place, Underground city',
#  'Christie']

# %% [markdown]
# # Some Summary Information about Neighborhoods inside "Downtown Toronto" Cont'd

# %%
neigh_venue_summary = dt_venues.groupby('Neighborhood').count()
neigh_venue_summary.drop(columns = ['Unnamed: 0']).head()
# Out:
#                                                     Postal Code  \
# Neighborhood
# Adelaide, King, Richmond                                    100
# Berczy Park                                                 100
# CN Tower, Bathurst Quay, Island airport, Harbou...           15
# Cabbagetown, St. James Town                                  38
# Central Bay Street                                          100
#
#                                                     Neighborhood Latitude  \
# Neighborhood
# Adelaide, King, Richmond                                              100
# Berczy Park                                                           100
# CN Tower, Bathurst Quay, Island airport, Harbou...                     15
# Cabbagetown, St. James Town                                            38
# Central Bay Street                                                    100
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Adelaide, King, Richmond                                               100
# Berczy Park                                                            100
# CN Tower, Bathurst Quay, Island airport, Harbou...                      15
# Cabbagetown, St. James Town                                             38
# Central Bay Street                                                     100
#
#                                                     Venue  Venue Summary  \
# Neighborhood
# Adelaide, King, Richmond                              100            100
# Berczy Park                                           100            100
# CN Tower, Bathurst Quay, Island airport, Harbou...     15             15
# Cabbagetown, St. James Town                            38             38
# Central Bay Street                                    100            100
#
#                                                     Venue Category  Distance
# Neighborhood
# Adelaide, King, Richmond                                       100       100
# Berczy Park                                                    100       100
# CN Tower, Bathurst Quay, Island airport, Harbou...              15        15
# Cabbagetown, St. James Town                                     38        38
# Central Bay Street                                             100       100

# %%
print('There are {} uniques categories.'.format(len(dt_venues['Venue Category'].unique())))

print('Here is the list of different categories:')
list(dt_venues['Venue Category'].unique())
# Out:
# There are 206 uniques categories.
# Here is the list of different categories:
# ['Grocery Store',
#  'BBQ Joint',
#  'Athletics & Sports',
#  'Filipino Restaurant',
#  'Pie Shop',
#  'Office',
#  'Park',
#  'Smoothie Shop',
#  'Japanese Restaurant',
#  'Coffee Shop',
#  'Breakfast Spot',
#  'Bank',
#  'Sandwich Place',
#  'Playground',
#  'Trail',
#  'Candy Store',
#  'Hostel',
#  'Convenience Store',
#  'Metro Station',
#  'Diner',
#  'Indian Restaurant',
#  'Italian Restaurant',
#  'Restaurant',
#  'Café',
#  'Jewelry Store',
#  'Gastropub',
#  'Pub',
#  'Farm',
#  'Pet Store',
#  'Caribbean Restaurant',
#  'Deli / Bodega',
#  'Taiwanese Restaurant',
#  'Gift Shop',
#  'Thai Restaurant',
#  'Steakhouse',
#  'Garden',
#  'Rock Club',
#  'Dance Studio',
#  'Pool',
#  'American Restaurant',
#  'Theater',
#  'Performing Arts Venue',
#  'Beer Store',
#  'Bubble Tea Shop',
#  'Theme Restaurant',
#  'Bookstore',
#  'Ramen Restaurant',
#  'Tea Room',
#  'Salon / Barbershop',
#  'Pizza Place',
#  'Juice Bar',
#  'Burger Joint',
#  'Mexican Restaurant',
#  'Hobby Shop',
#  'Gay Bar',
#  'Ice Cream Shop',
#  'Ethiopian Restaurant',
#  'General Entertainment',
#  'Creperie',
#  "Men's Store",
#  'Sushi Restaurant',
#  'Arts & Crafts Store',
#  'Smoke Shop',
#  'Gym',
#  'Wings Joint',
#  'Supermarket',
#  'Vietnamese Restaurant',
#  'Yoga Studio',
#  'Wine Shop',
#  'Dog Run',
#  'Historic Site',
#  'Nightclub',
#  'Sports Bar',
#  'Afghan Restaurant',
#  'Sake Bar',
#  'Mediterranean Restaurant',
#  'Portuguese Restaurant',
#  'Video Game Store',
#  'Chinese Restaurant',
#  'Health & Beauty Service',
#  'Seafood Restaurant',
#  'Comic Shop',
#  'Middle Eastern Restaurant',
#  'Video Store',
#  'Falafel Restaurant',
#  'Furniture / Home Store',
#  'Vegetarian / Vegan Restaurant',
#  'Hotel',
#  'Bakery',
#  'Gym / Fitness Center',
#  'Farmers Market',
#  'Spa',
#  'Chocolate Shop',
#  'Dessert Shop',
#  'Liquor Store',
#  'French Restaurant',
#  'Tech Startup',
#  'Spanish Restaurant',
#  'Animal Shelter',
#  'Event Space',
#  'Cosmetics Shop',
#  'Shoe Store',
#  'Bar',
#  'German Restaurant',
#  'Brewery',
#  'Food Truck',
#  'Gym Pool',
#  'Karaoke Bar',
#  'Electronics Store',
#  'Fast Food Restaurant',
#  'Auto Dealership',
#  'Skating Rink',
#  'Pharmacy',
#  'Clothing Store',
#  'Burrito Place',
#  'Plaza',
#  'Shopping Mall',
#  'Movie Theater',
#  'Taco Place',
#  'Concert Hall',
#  'Beer Bar',
#  'Food Court',
#  'Art Gallery',
#  'Miscellaneous Shop',
#  'Department Store',
#  'Neighborhood_Venue',
#  'Monument / Landmark',
#  'Art Museum',
#  'New American Restaurant',
#  'Accessories Store',
#  'Toy / Game Store',
#  'Church',
#  'Poke Place',
#  'Speakeasy',
#  'Cocktail Bar',
#  'Jazz Club',
#  'Museum',
#  'Latin American Restaurant',
#  'Bistro',
#  'Tailor Shop',
#  'Cheese Shop',
#  'Basketball Stadium',
#  'Sporting Goods Shop',
#  'Lounge',
#  'Fish Market',
#  'Belgian Restaurant',
#  'Beach',
#  'Bagel Shop',
#  'Fountain',
#  'Greek Restaurant',
#  'Salad Place',
#  'Lake',
#  'Train Station',
#  'Fried Chicken Joint',
#  'Comfort Food Restaurant',
#  'Tapas Restaurant',
#  'University',
#  'Wine Bar',
#  'Music Venue',
#  'Asian Restaurant',
#  'Noodle House',
#  'Opera House',
#  'Brazilian Restaurant',
#  'General Travel',
#  'Souvlaki Shop',
#  'Aquarium',
#  'Scenic Lookout',
#  'Baseball Stadium',
#  'History Museum',
#  'Hotel Bar',
#  'Track',
#  'College Gym',
#  'Gaming Cafe',
#  'Music School',
#  'Dumpling Restaurant',
#  'Doner Restaurant',
#  'Pastry Shop',
#  'Indie Movie Theater',
#  'Eastern European Restaurant',
#  'Hot Dog Joint',
#  'Organic Grocery',
#  'Record Shop',
#  'Persian Restaurant',
#  'Donut Shop',
#  'Gourmet Shop',
#  'Thrift / Vintage Store',
#  'Fish & Chips Shop',
#  'Martial Arts Dojo',
#  'Snack Place',
#  'Poutine Place',
#  'Airport',
#  'Harbor / Marina',
#  'Airport Lounge',
#  'Sculpture Garden',
#  'Korean Restaurant',
#  'South American Restaurant',
#  'Design Studio',
#  'Comedy Club',
#  'Cupcake Shop',
#  'Music Store',
#  'Health Food Store',
#  'School',
#  'Paper / Office Supplies Store',
#  'Jewish Restaurant',
#  'Rock Climbing Spot',
#  'Bridal Shop']

# %%
# Just for fun and deeper understanding
print(type(dt_venues[['Venue Category']]))

print(type(dt_venues['Venue Category']))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# # One-hot Encoding the "categroies" Column into Every Unique Categorical Feature.

# %%
# one hot encoding
dt_onehot = pd.get_dummies(data = dt_venues, drop_first  = False, 
                              prefix = "", prefix_sep = "", columns = ['Venue Category'])
# dt_onehot.head()
dt_onehot.describe()
# Out:
#         Unnamed: 0  Neighborhood Latitude  Neighborhood Longitude  \
# count  1576.000000            1576.000000             1576.000000
# mean    787.500000              43.653746              -79.384014
# std     455.096327               0.008899                0.013840
# min       0.000000              43.628947              -79.422564
# 25%     393.750000              43.647177              -79.387383
# 50%     787.500000              43.651494              -79.381752
# 75%    1181.250000              43.657952              -79.375418
# max    1575.000000              43.679563              -79.360636
#
#           Distance  Accessories Store  Afghan Restaurant      Airport  \
# count  1576.000000        1576.000000        1576.000000  1576.000000
# mean    486.595178           0.000635           0.000635     0.000635
# std     224.894546           0.025190           0.025190     0.025190
# min       9.000000           0.000000           0.000000     0.000000
# 25%     319.750000           0.000000           0.000000     0.000000
# 50%     463.000000           0.000000           0.000000     0.000000
# 75%     639.250000           0.000000           0.000000     0.000000
# max     999.000000           1.000000           1.000000     1.000000
#
#        Airport Lounge  American Restaurant  Animal Shelter     Aquarium  \
# count     1576.000000          1576.000000     1576.000000  1576.000000
# mean         0.000635             0.015863        0.000635     0.001904
# std          0.025190             0.124985        0.025190     0.043602
# min          0.000000             0.000000        0.000000     0.000000
# 25%          0.000000             0.000000        0.000000     0.000000
# 50%          0.000000             0.000000        0.000000     0.000000
# 75%          0.000000             0.000000        0.000000     0.000000
# max          1.000000             1.000000        1.000000     1.000000
#
#        Art Gallery   Art Museum  Arts & Crafts Store  Asian Restaurant  \
# count  1576.000000  1576.000000          1576.000000       1576.000000
# mean      0.010152     0.001904             0.004442          0.004442
# std       0.100278     0.043602             0.066518          0.066518
# min       0.000000     0.000000             0.000000          0.000000
# 25%       0.000000     0.000000             0.000000          0.000000
# 50%       0.000000     0.000000             0.000000          0.000000
# 75%       0.000000     0.000000             0.000000          0.000000
# max       1.000000     1.000000             1.000000          1.000000
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %% [markdown]
# # Manually Selecting (Subsetting) Related Features for the Grocery Contractor

# %%
important_list_of_features = ['Neighborhood',
 'Neighborhood Latitude',
 'Neighborhood Longitude',
 'Grocery Store',
 'BBQ Joint',
 'Filipino Restaurant',
 'Pie Shop',
 'Japanese Restaurant',
 'Breakfast Spot',
 'Sandwich Place',
 'Diner',
 'Indian Restaurant',
 'Italian Restaurant',
 'Restaurant',
 'Caribbean Restaurant',
 'Deli / Bodega',
 'Taiwanese Restaurant',
 'Thai Restaurant',
 'Steakhouse',
 'American Restaurant',
 'Theme Restaurant',
 'Ramen Restaurant',
 'Pizza Place',
 'Burger Joint',
 'Mexican Restaurant',
 'Ethiopian Restaurant',
 'General Entertainment',
 'Creperie',
 'Sushi Restaurant',
 'Wings Joint',
 'Supermarket',
 'Vietnamese Restaurant',
 'Afghan Restaurant',
 'Mediterranean Restaurant',
 'Portuguese Restaurant',
 'Chinese Restaurant',
 'Seafood Restaurant',
 'Middle Eastern Restaurant',
 'Falafel Restaurant',
 'Vegetarian / Vegan Restaurant',
 'Bakery',
 'Farmers Market',
 'French Restaurant',
 'Spanish Restaurant',
 'German Restaurant',
 'Food Truck',
 'Fast Food Restaurant',
 'Burrito Place',
 'Taco Place',
 'Food Court',
 'Latin American Restaurant',
 'Bistro',
 'Fish Market',
 'Belgian Restaurant',
 'Greek Restaurant',
 'Salad Place',
 'Fried Chicken Joint',
 'Comfort Food Restaurant',
 'Tapas Restaurant',
 'Asian Restaurant',
 'Noodle House',
 'Brazilian Restaurant',
 'Dumpling Restaurant',
 'Doner Restaurant',
 'Pastry Shop',
 'Eastern European Restaurant',
 'Hot Dog Joint',
 'Organic Grocery',
 'Persian Restaurant',
 'Donut Shop',
 'Gourmet Shop',
 'Fish & Chips Shop',
 'Korean Restaurant',
 'South American Restaurant',
 'Cupcake Shop',
 'Health Food Store',
 'Jewish Restaurant']

# %% [markdown]
# # Updating the One-hot Encoded DataFrame and
# # Grouping the Data by Neighborhoods

# %%
dt_onehot = dt_onehot[important_list_of_features].drop(columns = ['Neighborhood Latitude', 'Neighborhood Longitude'])
dt_onehot = dt_onehot.groupby('Neighborhood').sum()

# %%
dt_onehot.head()
# Out:
#                                                     Grocery Store  BBQ Joint  \
# Neighborhood
# Adelaide, King, Richmond                                        0          0
# Berczy Park                                                     1          1
# CN Tower, Bathurst Quay, Island airport, Harbou...              0          0
# Cabbagetown, St. James Town                                     0          0
# Central Bay Street                                              1          0
#
#                                                     Filipino Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                              0
# Berczy Park                                                           0
# CN Tower, Bathurst Quay, Island airport, Harbou...                    0
# Cabbagetown, St. James Town                                           1
# Central Bay Street                                                    0
#
#                                                     Pie Shop  \
# Neighborhood
# Adelaide, King, Richmond                                   0
# Berczy Park                                                0
# CN Tower, Bathurst Quay, Island airport, Harbou...         0
# Cabbagetown, St. James Town                                1
# Central Bay Street                                         0
#
#                                                     Japanese Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                              3
# Berczy Park                                                           3
# CN Tower, Bathurst Quay, Island airport, Harbou...                    0
# Cabbagetown, St. James Town                                           2
# Central Bay Street                                                    2
#
#                                                     Breakfast Spot  \
# Neighborhood
# Adelaide, King, Richmond                                         1
# Berczy Park                                                      3
# CN Tower, Bathurst Quay, Island airport, Harbou...               0
# Cabbagetown, St. James Town                                      0
# Central Bay Street                                               2
#
#                                                     Sandwich Place  Diner  \
# Neighborhood
# Adelaide, King, Richmond                                         0      0
# Berczy Park                                                      0      1
# CN Tower, Bathurst Quay, Island airport, Harbou...               0      0
# Cabbagetown, St. James Town                                      0      2
# Central Bay Street                                               1      1
#
#                                                     Indian Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                            0
# Berczy Park                                                         0
# CN Tower, Bathurst Quay, Island airport, Harbou...                  0
# Cabbagetown, St. James Town                                         1
# Central Bay Street                                                  0
#
#                                                     Italian Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                             0
# Berczy Park                                                          2
# CN Tower, Bathurst Quay, Island airport, Harbou...                   0
# Cabbagetown, St. James Town                                          1
# Central Bay Street                                                   2
#
#                                                     Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                     2
# Berczy Park                                                  3
# CN Tower, Bathurst Quay, Island airport, Harbou...           0
# Cabbagetown, St. James Town                                  1
# Central Bay Street                                           0
#
#                                                     Caribbean Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                               0
# Berczy Park                                                            0
# CN Tower, Bathurst Quay, Island airport, Harbou...                     0
# Cabbagetown, St. James Town                                            1
# Central Bay Street                                                     0
#
#                                                     Deli / Bodega  \
# Neighborhood
# Adelaide, King, Richmond                                        1
# Berczy Park                                                     1
# CN Tower, Bathurst Quay, Island airport, Harbou...              0
# Cabbagetown, St. James Town                                     1
# Central Bay Street                                              0
#
#                                                     Taiwanese Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                               0
# Berczy Park                                                            0
# CN Tower, Bathurst Quay, Island airport, Harbou...                     0
# Cabbagetown, St. James Town                                            1
# Central Bay Street                                                     0
#
#                                                     Thai Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                          2
# Berczy Park                                                       1
# CN Tower, Bathurst Quay, Island airport, Harbou...                0
# Cabbagetown, St. James Town                                       1
# Central Bay Street                                                2
#
#                                                     Steakhouse  \
# Neighborhood
# Adelaide, King, Richmond                                     2
# Berczy Park                                                  2
# CN Tower, Bathurst Quay, Island airport, Harbou...           0
# Cabbagetown, St. James Town                                  1
# Central Bay Street                                           1
#
#                                                     American Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                              3
# Berczy Park                                                           1
# CN Tower, Bathurst Quay, Island airport, Harbou...                    0
# Cabbagetown, St. James Town                                           1
# Central Bay Street                                                    1
#
#                                                     Theme Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                           0
# Berczy Park                                                        0
# CN Tower, Bathurst Quay, Island airport, Harbou...                 0
# Cabbagetown, St. James Town                                        0
# Central Bay Street                                                 0
#
#                                                     Ramen Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                           1
# Berczy Park                                                        0
# CN Tower, Bathurst Quay, Island airport, Harbou...                 0
# Cabbagetown, St. James Town                                        0
# Central Bay Street                                                 4
#
#                                                     Pizza Place  Burger Joint  \
# Neighborhood
# Adelaide, King, Richmond                                      2             1
# Berczy Park                                                   1             0
# CN Tower, Bathurst Quay, Island airport, Harbou...            0             0
# Cabbagetown, St. James Town                                   0             0
# Central Bay Street                                            2             2
#
#                                                     Mexican Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                             0
# Berczy Park                                                          0
# CN Tower, Bathurst Quay, Island airport, Harbou...                   0
# Cabbagetown, St. James Town                                          0
# Central Bay Street                                                   1
#
#                                                     Ethiopian Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                               0
# Berczy Park                                                            0
# CN Tower, Bathurst Quay, Island airport, Harbou...                     0
# Cabbagetown, St. James Town                                            0
# Central Bay Street                                                     0
#
#                                                     General Entertainment  \
# Neighborhood
# Adelaide, King, Richmond                                                0
# Berczy Park                                                             0
# CN Tower, Bathurst Quay, Island airport, Harbou...                      0
# Cabbagetown, St. James Town                                             0
# Central Bay Street                                                      0
#
#                                                     Creperie  \
# Neighborhood
# Adelaide, King, Richmond                                   0
# Berczy Park                                                1
# CN Tower, Bathurst Quay, Island airport, Harbou...         0
# Cabbagetown, St. James Town                                0
# Central Bay Street                                         1
#
#                                                     Sushi Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                           2
# Berczy Park                                                        0
# CN Tower, Bathurst Quay, Island airport, Harbou...                 0
# Cabbagetown, St. James Town                                        0
# Central Bay Street                                                 2
#
#                                                     Wings Joint  Supermarket  \
# Neighborhood
# Adelaide, King, Richmond                                      0            0
# Berczy Park                                                   0            1
# CN Tower, Bathurst Quay, Island airport, Harbou...            0            0
# Cabbagetown, St. James Town                                   0            0
# Central Bay Street                                            0            1
#
#                                                     Vietnamese Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                                0
# Berczy Park                                                             0
# CN Tower, Bathurst Quay, Island airport, Harbou...                      0
# Cabbagetown, St. James Town                                             0
# Central Bay Street                                                      0
#
#                                                     Afghan Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                            0
# Berczy Park                                                         0
# CN Tower, Bathurst Quay, Island airport, Harbou...                  0
# Cabbagetown, St. James Town                                         0
# Central Bay Street                                                  0
#
#                                                     Mediterranean Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                                   1
# Berczy Park                                                                0
# CN Tower, Bathurst Quay, Island airport, Harbou...                         0
# Cabbagetown, St. James Town                                                0
# Central Bay Street                                                         0
#
#                                                     Portuguese Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                                0
# Berczy Park                                                             0
# CN Tower, Bathurst Quay, Island airport, Harbou...                      0
# Cabbagetown, St. James Town                                             0
# Central Bay Street                                                      1
#
#                                                     Chinese Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                             0
# Berczy Park                                                          0
# CN Tower, Bathurst Quay, Island airport, Harbou...                   0
# Cabbagetown, St. James Town                                          0
# Central Bay Street                                                   2
#
#                                                     Seafood Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                             1
# Berczy Park                                                          1
# CN Tower, Bathurst Quay, Island airport, Harbou...                   0
# Cabbagetown, St. James Town                                          0
# Central Bay Street                                                   1
#
#                                                     Middle Eastern Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                                    0
# Berczy Park                                                                 1
# CN Tower, Bathurst Quay, Island airport, Harbou...                          0
# Cabbagetown, St. James Town                                                 0
# Central Bay Street                                                          1
#
#                                                     Falafel Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                             0
# Berczy Park                                                          0
# CN Tower, Bathurst Quay, Island airport, Harbou...                   0
# Cabbagetown, St. James Town                                          0
# Central Bay Street                                                   1
#
#                                                     Vegetarian / Vegan Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                                        2
# Berczy Park                                                                     0
# CN Tower, Bathurst Quay, Island airport, Harbou...                              0
# Cabbagetown, St. James Town                                                     0
# Central Bay Street                                                              2
#
#                                                     Bakery  Farmers Market  \
# Neighborhood
# Adelaide, King, Richmond                                 2               0
# Berczy Park                                              4               2
# CN Tower, Bathurst Quay, Island airport, Harbou...       0               0
# Cabbagetown, St. James Town                              0               0
# Central Bay Street                                       1               0
#
#                                                     French Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                            0
# Berczy Park                                                         1
# CN Tower, Bathurst Quay, Island airport, Harbou...                  0
# Cabbagetown, St. James Town                                         0
# Central Bay Street                                                  0
#
#                                                     Spanish Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                             0
# Berczy Park                                                          0
# CN Tower, Bathurst Quay, Island airport, Harbou...                   0
# Cabbagetown, St. James Town                                          0
# Central Bay Street                                                   0
#
#                                                     German Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                            0
# Berczy Park                                                         0
# CN Tower, Bathurst Quay, Island airport, Harbou...                  0
# Cabbagetown, St. James Town                                         0
# Central Bay Street                                                  0
#
#                                                     Food Truck  \
# Neighborhood
# Adelaide, King, Richmond                                     0
# Berczy Park                                                  1
# CN Tower, Bathurst Quay, Island airport, Harbou...           0
# Cabbagetown, St. James Town                                  0
# Central Bay Street                                           0
#
#                                                     Fast Food Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                               0
# Berczy Park                                                            0
# CN Tower, Bathurst Quay, Island airport, Harbou...                     0
# Cabbagetown, St. James Town                                            0
# Central Bay Street                                                     0
#
#                                                     Burrito Place  Taco Place  \
# Neighborhood
# Adelaide, King, Richmond                                        1           1
# Berczy Park                                                     0           0
# CN Tower, Bathurst Quay, Island airport, Harbou...              0           0
# Cabbagetown, St. James Town                                     0           0
# Central Bay Street                                              1           0
#
#                                                     Food Court  \
# Neighborhood
# Adelaide, King, Richmond                                     2
# Berczy Park                                                  0
# CN Tower, Bathurst Quay, Island airport, Harbou...           0
# Cabbagetown, St. James Town                                  0
# Central Bay Street                                           1
#
#                                                     Latin American Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                                    0
# Berczy Park                                                                 0
# CN Tower, Bathurst Quay, Island airport, Harbou...                          0
# Cabbagetown, St. James Town                                                 0
# Central Bay Street                                                          0
#
#                                                     Bistro  Fish Market  \
# Neighborhood
# Adelaide, King, Richmond                                 0            0
# Berczy Park                                              1            1
# CN Tower, Bathurst Quay, Island airport, Harbou...       0            0
# Cabbagetown, St. James Town                              0            0
# Central Bay Street                                       0            0
#
#                                                     Belgian Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                             0
# Berczy Park                                                          1
# CN Tower, Bathurst Quay, Island airport, Harbou...                   0
# Cabbagetown, St. James Town                                          0
# Central Bay Street                                                   0
#
#                                                     Greek Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                           1
# Berczy Park                                                        1
# CN Tower, Bathurst Quay, Island airport, Harbou...                 0
# Cabbagetown, St. James Town                                        0
# Central Bay Street                                                 0
#
#                                                     Salad Place  \
# Neighborhood
# Adelaide, King, Richmond                                      0
# Berczy Park                                                   1
# CN Tower, Bathurst Quay, Island airport, Harbou...            0
# Cabbagetown, St. James Town                                   0
# Central Bay Street                                            0
#
#                                                     Fried Chicken Joint  \
# Neighborhood
# Adelaide, King, Richmond                                              0
# Berczy Park                                                           1
# CN Tower, Bathurst Quay, Island airport, Harbou...                    0
# Cabbagetown, St. James Town                                           0
# Central Bay Street                                                    0
#
#                                                     Comfort Food Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                                  0
# Berczy Park                                                               1
# CN Tower, Bathurst Quay, Island airport, Harbou...                        0
# Cabbagetown, St. James Town                                               0
# Central Bay Street                                                        0
#
#                                                     Tapas Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                           0
# Berczy Park                                                        0
# CN Tower, Bathurst Quay, Island airport, Harbou...                 0
# Cabbagetown, St. James Town                                        0
# Central Bay Street                                                 1
#
#                                                     Asian Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                           2
# Berczy Park                                                        0
# CN Tower, Bathurst Quay, Island airport, Harbou...                 0
# Cabbagetown, St. James Town                                        0
# Central Bay Street                                                 0
#
#                                                     Noodle House  \
# Neighborhood
# Adelaide, King, Richmond                                       1
# Berczy Park                                                    0
# CN Tower, Bathurst Quay, Island airport, Harbou...             0
# Cabbagetown, St. James Town                                    0
# Central Bay Street                                             0
#
#                                                     Brazilian Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                               1
# Berczy Park                                                            0
# CN Tower, Bathurst Quay, Island airport, Harbou...                     0
# Cabbagetown, St. James Town                                            0
# Central Bay Street                                                     0
#
#                                                     Dumpling Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                              0
# Berczy Park                                                           0
# CN Tower, Bathurst Quay, Island airport, Harbou...                    0
# Cabbagetown, St. James Town                                           0
# Central Bay Street                                                    0
#
#                                                     Doner Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                           0
# Berczy Park                                                        0
# CN Tower, Bathurst Quay, Island airport, Harbou...                 0
# Cabbagetown, St. James Town                                        0
# Central Bay Street                                                 0
#
#                                                     Pastry Shop  \
# Neighborhood
# Adelaide, King, Richmond                                      0
# Berczy Park                                                   0
# CN Tower, Bathurst Quay, Island airport, Harbou...            0
# Cabbagetown, St. James Town                                   0
# Central Bay Street                                            0
#
#                                                     Eastern European Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                                      0
# Berczy Park                                                                   0
# CN Tower, Bathurst Quay, Island airport, Harbou...                            0
# Cabbagetown, St. James Town                                                   0
# Central Bay Street                                                            0
#
#                                                     Hot Dog Joint  \
# Neighborhood
# Adelaide, King, Richmond                                        0
# Berczy Park                                                     0
# CN Tower, Bathurst Quay, Island airport, Harbou...              0
# Cabbagetown, St. James Town                                     0
# Central Bay Street                                              0
#
#                                                     Organic Grocery  \
# Neighborhood
# Adelaide, King, Richmond                                          0
# Berczy Park                                                       0
# CN Tower, Bathurst Quay, Island airport, Harbou...                0
# Cabbagetown, St. James Town                                       0
# Central Bay Street                                                0
#
#                                                     Persian Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                             0
# Berczy Park                                                          0
# CN Tower, Bathurst Quay, Island airport, Harbou...                   0
# Cabbagetown, St. James Town                                          0
# Central Bay Street                                                   0
#
#                                                     Donut Shop  Gourmet Shop  \
# Neighborhood
# Adelaide, King, Richmond                                     0             0
# Berczy Park                                                  0             0
# CN Tower, Bathurst Quay, Island airport, Harbou...           0             0
# Cabbagetown, St. James Town                                  0             0
# Central Bay Street                                           0             0
#
#                                                     Fish & Chips Shop  \
# Neighborhood
# Adelaide, King, Richmond                                            0
# Berczy Park                                                         0
# CN Tower, Bathurst Quay, Island airport, Harbou...                  0
# Cabbagetown, St. James Town                                         0
# Central Bay Street                                                  0
#
#                                                     Korean Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                            0
# Berczy Park                                                         0
# CN Tower, Bathurst Quay, Island airport, Harbou...                  0
# Cabbagetown, St. James Town                                         0
# Central Bay Street                                                  0
#
#                                                     South American Restaurant  \
# Neighborhood
# Adelaide, King, Richmond                                                    0
# Berczy Park                                                                 0
# CN Tower, Bathurst Quay, Island airport, Harbou...                          0
# Cabbagetown, St. James Town                                                 0
# Central Bay Street                                                          0
#
#                                                     Cupcake Shop  \
# Neighborhood
# Adelaide, King, Richmond                                       0
# Berczy Park                                                    0
# CN Tower, Bathurst Quay, Island airport, Harbou...             0
# Cabbagetown, St. James Town                                    0
# Central Bay Street                                             0
#
#                                                     Health Food Store  \
# Neighborhood
# Adelaide, King, Richmond                                            0
# Berczy Park                                                         0
# CN Tower, Bathurst Quay, Island airport, Harbou...                  0
# Cabbagetown, St. James Town                                         0
# Central Bay Street                                                  0
#
#                                                     Jewish Restaurant
# Neighborhood
# Adelaide, King, Richmond                                            0
# Berczy Park                                                         0
# CN Tower, Bathurst Quay, Island airport, Harbou...                  0
# Cabbagetown, St. James Town                                         0
# Central Bay Street                                                  0

# %% [markdown]
# # Integrating Different Restaurants and Different Joints
# # (Assuming Different Resaturants Use the Same Raw Groceries)
# # This Assumption is made for simplicity and due to not having very large dataset about neighborhoods.

# %%
feat_name_list = list(dt_onehot.columns)
restaurant_list = []


for counter, value in enumerate(feat_name_list):
    if value.find('Restaurant') != (-1):
        restaurant_list.append(value)
        
dt_onehot['Total Restaurants'] = dt_onehot[restaurant_list].sum(axis = 1)
dt_onehot = dt_onehot.drop(columns = restaurant_list)


feat_name_list = list(dt_onehot.columns)
joint_list = []


for counter, value in enumerate(feat_name_list):
    if value.find('Joint') != (-1):
        joint_list.append(value)
        
dt_onehot['Total Joints'] = dt_onehot[joint_list].sum(axis = 1)
dt_onehot = dt_onehot.drop(columns = joint_list)

# %%
dt_onehot.head()
# Out:
#                                                     Grocery Store  Pie Shop  \
# Neighborhood
# Adelaide, King, Richmond                                        0         0
# Berczy Park                                                     1         0
# CN Tower, Bathurst Quay, Island airport, Harbou...              0         0
# Cabbagetown, St. James Town                                     0         1
# Central Bay Street                                              1         0
#
#                                                     Breakfast Spot  \
# Neighborhood
# Adelaide, King, Richmond                                         1
# Berczy Park                                                      3
# CN Tower, Bathurst Quay, Island airport, Harbou...               0
# Cabbagetown, St. James Town                                      0
# Central Bay Street                                               2
#
#                                                     Sandwich Place  Diner  \
# Neighborhood
# Adelaide, King, Richmond                                         0      0
# Berczy Park                                                      0      1
# CN Tower, Bathurst Quay, Island airport, Harbou...               0      0
# Cabbagetown, St. James Town                                      0      2
# Central Bay Street                                               1      1
#
#                                                     Deli / Bodega  Steakhouse  \
# Neighborhood
# Adelaide, King, Richmond                                        1           2
# Berczy Park                                                     1           2
# CN Tower, Bathurst Quay, Island airport, Harbou...              0           0
# Cabbagetown, St. James Town                                     1           1
# Central Bay Street                                              0           1
#
#                                                     Pizza Place  \
# Neighborhood
# Adelaide, King, Richmond                                      2
# Berczy Park                                                   1
# CN Tower, Bathurst Quay, Island airport, Harbou...            0
# Cabbagetown, St. James Town                                   0
# Central Bay Street                                            2
#
#                                                     General Entertainment  \
# Neighborhood
# Adelaide, King, Richmond                                                0
# Berczy Park                                                             0
# CN Tower, Bathurst Quay, Island airport, Harbou...                      0
# Cabbagetown, St. James Town                                             0
# Central Bay Street                                                      0
#
#                                                     Creperie  Supermarket  \
# Neighborhood
# Adelaide, King, Richmond                                   0            0
# Berczy Park                                                1            1
# CN Tower, Bathurst Quay, Island airport, Harbou...         0            0
# Cabbagetown, St. James Town                                0            0
# Central Bay Street                                         1            1
#
#                                                     Bakery  Farmers Market  \
# Neighborhood
# Adelaide, King, Richmond                                 2               0
# Berczy Park                                              4               2
# CN Tower, Bathurst Quay, Island airport, Harbou...       0               0
# Cabbagetown, St. James Town                              0               0
# Central Bay Street                                       1               0
#
#                                                     Food Truck  Burrito Place  \
# Neighborhood
# Adelaide, King, Richmond                                     0              1
# Berczy Park                                                  1              0
# CN Tower, Bathurst Quay, Island airport, Harbou...           0              0
# Cabbagetown, St. James Town                                  0              0
# Central Bay Street                                           0              1
#
#                                                     Taco Place  Food Court  \
# Neighborhood
# Adelaide, King, Richmond                                     1           2
# Berczy Park                                                  0           0
# CN Tower, Bathurst Quay, Island airport, Harbou...           0           0
# Cabbagetown, St. James Town                                  0           0
# Central Bay Street                                           0           1
#
#                                                     Bistro  Fish Market  \
# Neighborhood
# Adelaide, King, Richmond                                 0            0
# Berczy Park                                              1            1
# CN Tower, Bathurst Quay, Island airport, Harbou...       0            0
# Cabbagetown, St. James Town                              0            0
# Central Bay Street                                       0            0
#
#                                                     Salad Place  Noodle House  \
# Neighborhood
# Adelaide, King, Richmond                                      0             1
# Berczy Park                                                   1             0
# CN Tower, Bathurst Quay, Island airport, Harbou...            0             0
# Cabbagetown, St. James Town                                   0             0
# Central Bay Street                                            0             0
#
#                                                     Pastry Shop  \
# Neighborhood
# Adelaide, King, Richmond                                      0
# Berczy Park                                                   0
# CN Tower, Bathurst Quay, Island airport, Harbou...            0
# Cabbagetown, St. James Town                                   0
# Central Bay Street                                            0
#
#                                                     Organic Grocery  \
# Neighborhood
# Adelaide, King, Richmond                                          0
# Berczy Park                                                       0
# CN Tower, Bathurst Quay, Island airport, Harbou...                0
# Cabbagetown, St. James Town                                       0
# Central Bay Street                                                0
#
#                                                     Donut Shop  Gourmet Shop  \
# Neighborhood
# Adelaide, King, Richmond                                     0             0
# Berczy Park                                                  0             0
# CN Tower, Bathurst Quay, Island airport, Harbou...           0             0
# Cabbagetown, St. James Town                                  0             0
# Central Bay Street                                           0             0
#
#                                                     Fish & Chips Shop  \
# Neighborhood
# Adelaide, King, Richmond                                            0
# Berczy Park                                                         0
# CN Tower, Bathurst Quay, Island airport, Harbou...                  0
# Cabbagetown, St. James Town                                         0
# Central Bay Street                                                  0
#
#                                                     Cupcake Shop  \
# Neighborhood
# Adelaide, King, Richmond                                       0
# Berczy Park                                                    0
# CN Tower, Bathurst Quay, Island airport, Harbou...             0
# Cabbagetown, St. James Town                                    0
# Central Bay Street                                             0
#
#                                                     Health Food Store  \
# Neighborhood
# Adelaide, King, Richmond                                            0
# Berczy Park                                                         0
# CN Tower, Bathurst Quay, Island airport, Harbou...                  0
# Cabbagetown, St. James Town                                         0
# Central Bay Street                                                  0
#
#                                                     Total Restaurants  \
# Neighborhood
# Adelaide, King, Richmond                                           21
# Berczy Park                                                        16
# CN Tower, Bathurst Quay, Island airport, Harbou...                  0
# Cabbagetown, St. James Town                                        10
# Central Bay Street                                                 23
#
#                                                     Total Joints
# Neighborhood
# Adelaide, King, Richmond                                       1
# Berczy Park                                                    2
# CN Tower, Bathurst Quay, Island airport, Harbou...             0
# Cabbagetown, St. James Town                                    0
# Central Bay Street                                             2

# %% [markdown]
# # Run k-means to Cluster Neighborhoods into 5 Clusters

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans

# run k-means clustering
kmeans = KMeans(n_clusters = 5, random_state = 0).fit(dt_onehot)

# %% [markdown]
# # Showing Centers of Each Cluster

# %%
means_df = pd.DataFrame(kmeans.cluster_centers_)
means_df.columns = dt_onehot.columns
means_df.index = ['G1','G2','G3','G4','G5']
means_df['Total Sum'] = means_df.sum(axis = 1)
means_df.sort_values(axis = 0, by = ['Total Sum'], ascending=False)
# Out:
#     Grocery Store      Pie Shop  Breakfast Spot  Sandwich Place  Diner  \
# G5          3.500  0.000000e+00            0.50            1.00    2.0
# G3          0.500  0.000000e+00            0.50            0.50    0.0
# G4          0.375 -2.775558e-17            1.50            0.25    1.0
# G1          0.500  2.500000e-01            1.25            0.00    1.0
# G2          1.000  5.000000e-01            0.50            0.50    0.0
#
#     Deli / Bodega  Steakhouse  Pizza Place  General Entertainment  Creperie  \
# G5          0.500        0.50          2.0           5.000000e-01       0.5
# G3          0.000        0.00          1.5           0.000000e+00       0.5
# G4          0.875        1.75          1.5          -1.387779e-17       0.5
# G1          1.250        1.50          1.0           0.000000e+00       0.5
# G2          0.000        0.00          0.0           0.000000e+00       0.0
#
#     Supermarket  Bakery  Farmers Market  Food Truck  Burrito Place  \
# G5        0.500     0.5           0.000       0.000           0.00
# G3        1.000     5.0           1.000       0.000           1.00
# G4        0.375     2.0           0.625       0.625           0.75
# G1        0.500     2.0           1.000       0.500           0.00
# G2        0.000     0.0           0.000       0.000           0.00
#
#     Taco Place  Food Court  Bistro  Fish Market  Salad Place  Noodle House  \
# G5        0.50       0.000    0.00          0.0        0.000           0.0
# G3        0.00       0.500    0.00          0.5        0.000           0.5
# G4        0.25       0.875    0.25          0.0        0.375           0.5
# G1        0.00       0.000    0.75          0.5        0.750           0.0
# G2        0.00       0.000    0.00          0.0        0.000           0.0
#
#      Pastry Shop  Organic Grocery    Donut Shop  Gourmet Shop  \
# G5  0.000000e+00     0.000000e+00  0.000000e+00  0.000000e+00
# G3  5.000000e-01     1.000000e+00  1.000000e+00  5.000000e-01
# G4 -1.387779e-17    -2.775558e-17 -2.775558e-17 -1.387779e-17
# G1  0.000000e+00     0.000000e+00  0.000000e+00  0.000000e+00
# G2  0.000000e+00     0.000000e+00  0.000000e+00  0.000000e+00
#
#     Fish & Chips Shop  Cupcake Shop  Health Food Store  Total Restaurants  \
# G5       0.000000e+00  5.000000e-01       5.000000e-01             32.000
# G3       5.000000e-01  0.000000e+00       0.000000e+00             28.000
# G4      -1.387779e-17 -1.387779e-17      -1.387779e-17             21.875
# G1       0.000000e+00  0.000000e+00       0.000000e+00             14.250
# G2       0.000000e+00  0.000000e+00       0.000000e+00              1.000
#
#     Total Joints  Total Sum
# G5          2.50      48.00
# G3          2.00      46.50
# G4          1.25      37.50
# G1          1.75      29.25
# G2          0.50       4.00

# %% [markdown]
# # Result:
# # Best Group is G5;
# # Second Best Group is G3;
# # Third Best Group is G4;
# # Inserting "kmeans.labels_" into the Original Scarborough DataFrame
# # Finding the Corresponding Group for Each Neighborhood.

# %%
neigh_summary = pd.DataFrame([dt_data['Neighborhood'], 1 + kmeans.labels_]).T
neigh_summary.columns = ['Neighborhood', 'Group']
neigh_summary
# Out:
#                                          Neighborhood Group
# 0                                            Rosedale     4
# 1                         Cabbagetown, St. James Town     1
# 2                                Church and Wellesley     2
# 3                           Harbourfront, Regent Park     1
# 4                            Ryerson, Garden District     4
# 5                                      St. James Town     3
# 6                                         Berczy Park     5
# 7                                  Central Bay Street     5
# 8                            Adelaide, King, Richmond     4
# 9   Harbourfront East, Toronto Islands, Union Station     4
# 10           Design Exchange, Toronto Dominion Centre     4
# 11                     Commerce Court, Victoria Hotel     3
# 12                     Harbord, University of Toronto     1
# 13          Chinatown, Grange Park, Kensington Market     4
# 14  CN Tower, Bathurst Quay, Island airport, Harbo...     2
# 15                    Stn A PO Boxes 25 The Esplanade     4
# 16             First Canadian Place, Underground city     4
# 17                                           Christie     1

# %% [markdown]
# # Deducing Results:

# %% [markdown]
# # Best Neighborhood Are...

# %%
neigh_summary[neigh_summary['Group'] == 5]
# Out:
#          Neighborhood Group
# 6         Berczy Park     5
# 7  Central Bay Street     5

# %%
name_of_neigh = list(neigh_summary[neigh_summary['Group'] == 5]['Neighborhood'])[0]
dt_venues[dt_venues['Neighborhood'] == name_of_neigh].iloc[0,1:5].to_dict()
# Out:
# {'Postal Code': 'M5E',
#  'Neighborhood': 'Berczy Park',
#  'Neighborhood Latitude': 43.644770799999996,
#  'Neighborhood Longitude': -79.3733064}

# %%
name_of_neigh = list(neigh_summary[neigh_summary['Group'] == 5]['Neighborhood'])[1]
dt_venues[dt_venues['Neighborhood'] == name_of_neigh].iloc[0,1:5].to_dict()
# Out:
# {'Postal Code': 'M5G',
#  'Neighborhood': 'Central Bay Street',
#  'Neighborhood Latitude': 43.6579524,
#  'Neighborhood Longitude': -79.3873826}

# %% [markdown]
# # Second Best Neighborhoods

# %%
neigh_summary[neigh_summary['Group'] == 3]
# Out:
#                       Neighborhood Group
# 5                   St. James Town     3
# 11  Commerce Court, Victoria Hotel     3

# %% [markdown]
# # Third Best Neighborhood

# %%
neigh_summary[neigh_summary['Group'] == 4]
# Out:
#                                          Neighborhood Group
# 0                                            Rosedale     4
# 4                            Ryerson, Garden District     4
# 8                            Adelaide, King, Richmond     4
# 9   Harbourfront East, Toronto Islands, Union Station     4
# 10           Design Exchange, Toronto Dominion Centre     4
# 13          Chinatown, Grange Park, Kensington Market     4
# 15                    Stn A PO Boxes 25 The Esplanade     4
# 16             First Canadian Place, Underground city     4

# %%
name_of_neigh = list(neigh_summary[neigh_summary['Group'] == 4]['Neighborhood'])[0]
dt_venues[dt_venues['Neighborhood'] == name_of_neigh].iloc[0,1:5].to_dict()
# Out:
# {'Postal Code': 'M4W',
#  'Neighborhood': 'Rosedale',
#  'Neighborhood Latitude': 43.6795626,
#  'Neighborhood Longitude': -79.37752940000001}
